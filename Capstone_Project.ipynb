# %% [markdown]
# ### End-to-End Story Telling project on real-world dataset​

# %% [markdown]
# # **OBJECTIVE**
#
# Conducting Exploratory Data Analysis (EDA) on a dataset containing information about write some description for the data set basis

# %% [markdown]
# ## Steps to Conduct EDA

# %% [markdown]
# ## Step 1: Data Collection and Loading
# Obtain the dataset (students_performance.csv).
#
# Load the dataset using a data manipulation library such as Pandas in Python.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Insights for Lung Cancer Prediction Dataset
#
# ## Columns Overview
#
# 1. **GENDER**: Categorical variable representing the gender of the individual.
#    - Values: Male, Female, or other possible categories.
#    - Insights: Gender-specific trends in lung cancer risk.
#
# 2. **AGE**: Numerical variable representing the age of the individual.
#    - Insights: Age distribution and its correlation with lung cancer prevalence.
#
# 3. **SMOKING**: Binary variable indicating if the individual is a smoker.
#    - Values: Yes (1), No (0).
#    - Insights: Smoking's impact on lung cancer risk.
#
# 4. **YELLOW_FINGERS**: Binary variable indicating the presence of yellow fingers due to smoking.
#    - Values: Yes (1), No (0).
#    - Insights: Indicator of heavy smoking habits.
#
# 5. **ANXIETY**: Binary variable showing if the individual experiences anxiety.
#    - Values: Yes (1), No (0).
#    - Insights: Possible link between mental health and lung cancer.
#
# 6. **PEER_PRESSURE**: Binary variable indicating if peer pressure affects smoking habits.
#    - Values: Yes (1), No (0).
#    - Insights: Social factors influencing smoking.
#
# 7. **CHRONIC_DISEASE**: Binary variable indicating the presence of chronic diseases.
#    - Values: Yes (1), No (0).
#    - Insights: Co-occurring conditions and lung cancer.
#
# 8. **FATIGUE**: Binary variable showing if the individual experiences fatigue.
#    - Values: Yes (1), No (0).
#    - Insights: Early symptoms or associated conditions.
#
# 9. **ALLERGY**: Binary variable indicating allergies.
#    - Values: Yes (1), No (0).
#    - Insights: Allergies as a confounding factor.
#
# 10. **WHEEZING**: Binary variable showing wheezing symptoms.
#     - Values: Yes (1), No (0).
#     - Insights: Respiratory symptoms linked to lung conditions.
#
# 11. **ALCOHOL_CONSUMING**: Binary variable indicating alcohol consumption.
#     - Values: Yes (1), No (0).
#     - Insights: Lifestyle factors and their correlation with lung cancer.
#
# 12. **COUGHING**: Binary variable for the presence of coughing symptoms.
#     - Values: Yes (1), No (0).
#     - Insights: Common symptom of lung issues.
#
# 13. **SHORTNESS_OF_BREATH**: Binary variable indicating shortness of breath.
#     - Values: Yes (1), No (0).
#     - Insights: Symptom analysis in lung cancer cases.
#
# 14. **SWALLOWING_DIFFICULTY**: Binary variable for swallowing difficulties.
#     - Values: Yes (1), No (0).
#     - Insights: Potential late-stage symptom.
#
# 15. **CHEST_PAIN**: Binary variable indicating chest pain.
#     - Values: Yes (1), No (0).
#     - Insights: Key symptom in diagnosis.
#
# 16. **LUNG_CANCER**: Target variable indicating the presence of lung cancer.
#     - Values: Yes (1), No (0).
#     - Insights: Outcome variable for prediction.

# %%
import pandas as pd
df = pd.read_csv(r'lung_cancer.csv')
print(df.head())
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   65        1               1        1              2
# 1      F   55        1               2        2              1
# 2      F   78        2               2        1              1
# 3      M   60        2               1        1              1
# 4      F   80        1               1        2              1
#
#    CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0                2        1        2         2                  2         2
# 1                1        2        2         2                  1         1
# 2                1        2        1         2                  1         1
# 3                2        1        2         1                  1         2
# 4                1        2        1         2                  1         1
#
#    SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN LUNG_CANCER
# ...

# %%
df.describe(include='all')
# Out:
#        GENDER          AGE      SMOKING  YELLOW_FINGERS      ANXIETY  \
# count    3000  3000.000000  3000.000000     3000.000000  3000.000000
# unique      2          NaN          NaN             NaN          NaN
# top         M          NaN          NaN             NaN          NaN
# freq     1514          NaN          NaN             NaN          NaN
# mean      NaN    55.169000     1.491000        1.514000     1.494000
# std       NaN    14.723746     0.500002        0.499887     0.500047
# min       NaN    30.000000     1.000000        1.000000     1.000000
# 25%       NaN    42.000000     1.000000        1.000000     1.000000
# 50%       NaN    55.000000     1.000000        2.000000     1.000000
# 75%       NaN    68.000000     2.000000        2.000000     2.000000
# max       NaN    80.000000     2.000000        2.000000     2.000000
#
#         PEER_PRESSURE  CHRONIC_DISEASE      FATIGUE      ALLERGY     WHEEZING  \
# ...

# %% [markdown]
# ## Step 2: Data Cleaning
# Check for missing values and handle them appropriately.
#
# Correct any inconsistencies in the data.
#
# Ensure all data types are appropriate.

# %%
# Check for missing values
print(df.isnull().sum())

# Fill missing values or drop them if necessary
df.fillna(method='ffill', inplace=True)

# Check data types
print(df.dtypes)

# Convert data types if necessary
#df['Age'] = df['Age'].astype(int)
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC_DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL_CONSUMING        0
# COUGHING                 0
# SHORTNESS_OF_BREATH      0
# SWALLOWING_DIFFICULTY    0
# CHEST_PAIN               0
# LUNG_CANCER              0
# dtype: int64
# GENDER                   object
# AGE                       int64
# SMOKING                   int64
# YELLOW_FINGERS            int64
# ANXIETY                   int64
# PEER_PRESSURE             int64
# CHRONIC_DISEASE           int64
# FATIGUE                   int64
# ALLERGY                   int64
# WHEEZING                  int64
# ALCOHOL_CONSUMING         int64
# COUGHING                  int64
# SHORTNESS_OF_BREATH       int64
# SWALLOWING_DIFFICULTY     int64
# CHEST_PAIN                int64
# ...

# %%
df['GENDER'] = df['GENDER'].map({'M': 0, 'F': 1})

# %% [markdown]
# ## Step 3: Data Visualization
# Use visualizations to understand the distribution and relationships between variables.
# Create histograms, box plots, scatter plots, bar charts, and heatmaps.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you already have your data loaded in a DataFrame called df

plt.figure(figsize=(16, 12))  # Set the overall figure size

# Subplot 1: Gender distribution
plt.subplot(221)
df['GENDER'].value_counts().plot(kind='bar', title='Gender Distribution')
plt.xticks(rotation=0)

# Subplot 2: Smoking status
plt.subplot(222)
df['SMOKING'].value_counts().plot(kind='bar', title='Smoking Status')
plt.xticks(rotation=0)

plt.tight_layout()  # Adjust subplots to fit into the figure area nicely
plt.show()

# %% [markdown]
# # Insights from Data Visualization
#
# ## 1. Gender Distribution
# - **Objective**: To understand the distribution of gender in the dataset.
# - **Visualization**: Bar chart displaying the count of each gender category (e.g., Male, Female).
# - **Insights**:
#   - Helps identify any gender imbalance in the dataset.
#   - Useful for analyzing gender-specific trends in lung cancer prediction.
#
# ## 2. Smoking Status
# - **Objective**: To examine the proportion of individuals who smoke.
# - **Visualization**: Bar chart showing the count of smokers and non-smokers.
# - **Insights**:
#   - Highlights the prevalence of smoking in the population.
#   - Useful for assessing the impact of smoking as a risk factor for lung cancer.
#   - Can reveal if smoking is a significant variable in the dataset.

# %%
df.boxplot(rot=90, figsize=(12, 8))  # Use rot instead of rotation
plt.title('Boxplot of Numeric Columns')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# # Insights from Boxplot of Numeric Columns
#
# ## Visualization Description
# - **Objective**: To analyze the distribution, spread, and outliers for each numeric column in the dataset.
# - **Visualization**: A boxplot for all numeric columns in the dataset.
#
# ## Key Insights
# 1. **Central Tendency**:
#    - The median (central line in each box) represents the typical value for each numeric column.
#    - Provides an overview of how values are distributed across the dataset.
#
# 2. **Spread of Data**:
#    - The interquartile range (IQR, represented by the box) shows the spread of the middle 50% of values.
#    - Longer boxes indicate higher variability, while shorter boxes indicate consistency in values.
#
# 3. **Outliers**:
#    - Points outside the "whiskers" represent outliers.
#    - Outliers might indicate rare cases or errors in the data that may need further investigation.
#
# 4. **Numeric Columns Comparison**:
#    - By visualizing all numeric columns together, it's easier to compare their ranges and variability.
#    - Columns with significantly different scales may need normalization for machine learning models.

# %%
sns.histplot(df['AGE'], kde=True, bins=20, color='orange')  # Set bar color to 'skyblue'
plt.title('Age Distribution with KDE')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Insights from Age Distribution Histogram with KDE
#
# ## Visualization Description
# - **Objective**: To analyze the distribution of the `AGE` column and observe the general trends in age within the dataset.
# - **Visualization**: A histogram with 20 bins, displaying the frequency of ages, complemented by a Kernel Density Estimate (KDE) curve to show the distribution.
#
# ## Key Insights
# 1. **Age Distribution**:
#    - The histogram provides a visual representation of how ages are distributed across the dataset.
#    - Peaks in the KDE curve indicate the most common age ranges.
#
# 2. **Frequency of Ages**:
#    - The height of the bars shows the count of individuals within specific age ranges.
#    - Wider bars (bins) indicate a broader grouping of ages, while narrower bars offer more granularity.
#
# 3. **General Trends**:
#    - The KDE curve smooths out the distribution, helping identify patterns that may not be immediately obvious from the bars.
#    - This can reveal whether the dataset has a normal distribution, skewness, or multimodal characteristics.
#
# 4. **Potential Age-Related Insights**:
#    - Useful for identifying age groups most at risk of lung cancer.
#    - Can help segment the population for further analysis based on age.

# %%
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Plot for WHEEZING
sns.histplot(df['WHEEZING'], kde=True, ax=axes[0], color='orange')
axes[0].set_title('Wheezing Distribution')
axes[0].set_xlabel('Wheezing (1 = Yes, 0 = No)')

# Plot for CHEST_PAIN
sns.histplot(df['CHEST_PAIN'], kde=True, ax=axes[1], color='blue')
axes[1].set_title('Chest Pain Distribution')
axes[1].set_xlabel('Chest Pain (1 = Yes, 0 = No)')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Insights from Wheezing and Chest Pain Distributions
#
# ## Visualization Description
# - **Objective**: To analyze the distribution of two key variables, `WHEEZING` and `CHEST_PAIN`, which are potential indicators of lung cancer.
# - **Visualization**:
#   - **Left Plot**: Wheezing distribution with an orange color scheme.
#   - **Right Plot**: Chest pain distribution with a blue color scheme.
#   - Both include KDE curves for smoother trend analysis.
#
# ---
#
# ## Left Plot: Wheezing Distribution
# - **Insights**:
#   1. Highlights the proportion of individuals experiencing wheezing symptoms.
#   2. The KDE curve provides a smooth representation of the occurrence of wheezing.
#   3. High frequency of wheezing (1 = Yes) may suggest respiratory issues in a significant portion of the population.
#
# - **Suggestions**:
#   - Explore the relationship between wheezing and other symptoms like `COUGHING` or `SHORTNESS_OF_BREATH`.
#   - Investigate its correlation with the target variable `LUNG_CANCER`.
#
# ---
#
# ## Right Plot: Chest Pain Distribution
# - **Insights**:
#   1. Displays the occurrence of chest pain in the dataset.
#   2. The KDE curve reveals the trend of individuals reporting chest pain.
#   3. A high occurrence of chest pain (1 = Yes) might indicate severe respiratory or cardiac conditions.
#
# - **Suggestions**:
#   - Compare chest pain prevalence across age groups or genders.
#   - Analyze its combined effect with variables like `SMOKING` or `ANXIETY` on lung cancer prediction.
#
# ---

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot the correlation heatmap for selected numerical columns
plt.figure(figsize=(10, 6))
corr = df[['AGE', 'FATIGUE', 'CHRONIC_DISEASE', 'SMOKING', 'ANXIETY']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Health Factors')
plt.show()

# %% [markdown]
# # Insights from Correlation Heatmap of Health Factors
#
# ## Visualization Description
# - **Objective**: To analyze the relationships between selected numerical health factors: `AGE`, `FATIGUE`, `CHRONIC_DISEASE`, `SMOKING`, and `ANXIETY`.
# - **Visualization**: A heatmap showing the correlation coefficients between these variables, with color intensity indicating the strength and direction of the relationship.
#   - **Positive Correlation**: Values closer to +1 indicate that as one variable increases, the other also tends to increase.
#   - **Negative Correlation**: Values closer to -1 indicate that as one variable increases, the other tends to decrease.
#   - **No Correlation**: Values near 0 indicate no significant relationship between the variables.
#
# ---
#
# ## Key Insights
# 1. **Age and Other Factors**:
#    - Examine whether `AGE` has any strong correlation with other variables like `FATIGUE` or `CHRONIC_DISEASE`.
#    - A high positive or negative correlation with `AGE` may indicate age-related trends.
#
# 2. **Smoking and Chronic Disease**:
#    - The correlation between `SMOKING` and `CHRONIC_DISEASE` could highlight the impact of smoking on long-term health conditions.
#    - A positive correlation may suggest a link between smoking habits and chronic health issues.
#
# 3. **Anxiety and Fatigue**:
#    - If `ANXIETY` and `FATIGUE` show a positive correlation, it could imply that anxiety levels contribute to feelings of fatigue.
#    - This insight could be relevant for understanding mental health’s impact on physical well-being.
#
# 4. **Overall Trends**:
#    - Strong correlations (closer to +1 or -1) indicate potential predictors or relationships worth exploring further.
#    - Weak correlations (closer to 0) suggest independence between variables.
#
# ---

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='GENDER', y='SMOKING', data=df)
plt.title('Smoking Status by Gender')
plt.xlabel('Gender')
plt.ylabel('Smoking Status')
plt.xticks([0, 1], ['Male', 'Female'])  # Ensure these labels correspond to your dataset encoding
plt.show()

# %% [markdown]
# # Insights from Smoking Status by Gender Boxplot
#
# ## Visualization Description
# - **Objective**: To analyze the distribution of smoking status (`SMOKING`) across different genders (`GENDER`).
# - **Visualization**: A boxplot showing the variation of smoking status for males and females in the dataset.
#
# ---
#
# ## Key Insights
# 1. **Gender Differences**:
#    - The boxplot provides a clear comparison of smoking behavior between male and female individuals.
#    - Look for differences in the spread of the data, central tendencies (median), and any potential outliers.
#
# 2. **Smoking Status Variation**:
#    - The boxplot reveals how the smoking status is distributed within each gender. If the data is coded with `0` (non-smoker) and `1` (smoker), you can observe the number of smokers in each group.
#
# 3. **Outliers**:
#    - Check for any extreme values (outliers) in the distribution of smoking status.
#    - These outliers could represent rare cases where smoking status is significantly different from the rest of the group.
#
# ---

# %%
# Line plot for Age vs Smoking Status for Lung Cancer Prediction
plt.figure(figsize=(10, 6))
# Grouping by age and calculating average smoking status
age_smoking_trends = df.groupby('AGE')['SMOKING'].mean().reset_index()
sns.lineplot(data=age_smoking_trends, x='AGE', y='SMOKING', marker='o')
plt.title('Trends in Smoking Status by Age for Lung Cancer Prediction')
plt.xlabel('Age')
plt.ylabel('Average Smoking Status')
plt.show()

# %% [markdown]
# # Insights from Age vs Smoking Status for Lung Cancer Prediction
#
# ## Visualization Description
# - **Objective**: To analyze how smoking status changes across different age groups and its potential impact on lung cancer prediction.
# - **Visualization**: A line plot that shows the trend of smoking status (non-smoker vs smoker) as individuals age.
#
# ---
#
# ## Key Insights
# 1. **Age and Smoking Trend**:
#    - The plot helps identify how smoking behavior changes across different age groups.
#    - For instance, the plot may show that younger individuals are less likely to smoke, but as individuals age, smoking becomes more common, or vice versa.
#
# 2. **Smoking Prevalence Across Ages**:
#    - If the trend shows increasing smoking prevalence with age, it could indicate that smoking is a significant factor in lung cancer risk as people age.
#    - Alternatively, a decreasing trend may suggest more people are quitting smoking as they grow older.
#
# 3. **Implications for Lung Cancer Prediction**:
#    - Understanding the smoking pattern across different age groups can provide insights into predicting lung cancer risk based on both age and smoking history.
#
# ---

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='ANXIETY', y='FATIGUE', hue='GENDER', data=df)
plt.title('Anxiety vs Fatigue by Gender')
plt.xlabel('Anxiety Level')
plt.ylabel('Fatigue Level')
plt.show()

# %% [markdown]
# # Insights from Anxiety vs Fatigue by Gender Scatter Plot
#
# ## Visualization Description
# - **Objective**: To visualize the relationship between `ANXIETY` and `FATIGUE` levels, with gender as the hue to distinguish between male and female individuals.
# - **Visualization**: A scatter plot showing the correlation between anxiety and fatigue, colored by gender, to reveal any trends or differences.
#
# ---
#
# ## Key Insights
# 1. **Anxiety and Fatigue Relationship**:
#    - The scatter plot helps to identify if there is a correlation between anxiety and fatigue levels.
#    - A positive correlation would show that higher anxiety levels tend to coincide with higher fatigue levels.
#
# 2. **Gender-Based Differences**:
#    - By using color coding for gender, the plot can highlight potential gender-based differences in anxiety and fatigue levels.
#    - If there’s a visible separation between the two genders, it could indicate that anxiety and fatigue levels vary based on gender.
#
# 3. **Clusters**:
#    - Look for any clustering of data points. A tight cluster suggests consistent levels of anxiety or fatigue, while a more spread-out scatter indicates varied experiences of anxiety and fatigue.
#
# 4. **Outliers**:
#    - Identify any data points that stand apart from the rest of the plot, which could represent individuals with unusually high or low anxiety or fatigue levels.
#
# ---

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='AGE', y='SMOKING', hue='CHRONIC_DISEASE', palette='cool', data=df)
plt.title('Age vs Smoking by Chronic Disease')
plt.xlabel('Age')
plt.ylabel('Smoking Status')
plt.legend(title='Chronic Disease')
plt.show()

# %% [markdown]
# # Insights from Age vs Smoking by Chronic Disease Scatter Plot
#
# ## Visualization Description
# - **Objective**: To explore the relationship between `AGE` and `SMOKING` while categorizing the data by the presence of `CHRONIC_DISEASE`.
# - **Visualization**: A scatter plot where:
#   - **X-axis** represents `AGE`.
#   - **Y-axis** represents `SMOKING` (coded typically as 0 for non-smoker, 1 for smoker).
#   - Data points are colored by `CHRONIC_DISEASE` using the `cool` palette to visually differentiate between those with and without chronic disease.
#
# ---
#
# ## Key Insights
# 1. **Age and Smoking Status**:
#    - The plot shows how smoking status varies with age. By observing the distribution of smoking individuals across different age groups, trends such as smoking being more common in younger or older individuals may emerge.
#    - It can also help identify whether smoking is more prevalent among a specific age group or if it’s fairly consistent across all ages.
#
# 2. **Chronic Disease and Smoking**:
#    - The coloring of data points by `CHRONIC_DISEASE` highlights the relationship between chronic disease and smoking.
#    - You might observe if individuals with chronic diseases are more likely to be smokers or if non-smokers tend to have higher rates of chronic disease.
#
# 3. **Age Groups with Chronic Disease**:
#    - The distribution of chronic disease cases across age groups can provide insights into whether older individuals with chronic diseases are more or less likely to smoke.
#    - The plot may reveal if certain age groups have higher smoking rates when chronic disease is present.
#
# ---

# %% [markdown]
# ## Step 4: Descriptive Statistics
# Calculate and interpret measures of central tendency and dispersion.
# Summarize key statistics for numerical variables.

# %%
# Descriptive statistics for the 'AGE' column
age_description = df['AGE'].describe()

# Central tendency and dispersion for AGE
mean_age = df['AGE'].mean()
median_age = df['AGE'].median()
std_age = df['AGE'].std()

# Display the full description
print(age_description)

# Print mean, median, and standard deviation
print(f"Mean Age: {mean_age}")
print(f"Median Age: {median_age}")
print(f"Standard Deviation of Age: {std_age}")
# Out:
# count    3000.000000
# mean       55.169000
# std        14.723746
# min        30.000000
# 25%        42.000000
# 50%        55.000000
# 75%        68.000000
# max        80.000000
# Name: AGE, dtype: float64
# Mean Age: 55.169
# Median Age: 55.0
# Standard Deviation of Age: 14.723746191123832

# %% [markdown]
# ## Step 5: Identify Patterns and Relationships
# Use correlation analysis to identify relationships between variables.
# Perform bivariate and multivariate analyses.

# %%
# Correlation between 'AGE' and 'FATIGUE'
correlation_age_fatigue = df['AGE'].corr(df['FATIGUE'])
print(f"Correlation between Age and Fatigue: {correlation_age_fatigue}")
# Grouped analysis of average values by GENDER and CHRONIC_DISEASE
grouped_analysis = df.groupby(['GENDER', 'CHRONIC_DISEASE'])[['AGE', 'FATIGUE', 'SMOKING']].mean().reset_index()
print(grouped_analysis)
# Out:
# Correlation between Age and Fatigue: -0.0023218954096627656
#    GENDER  CHRONIC_DISEASE        AGE   FATIGUE   SMOKING
# 0       0                1  55.938859  1.502717  1.457880
# 1       0                2  54.751928  1.479434  1.494859
# 2       1                1  55.168707  1.465306  1.477551
# 3       1                2  54.846871  1.511318  1.532623

# %% [markdown]
# ## Step 6: Outlier Detection
# Identify and handle outliers using visualizations and statistical methods.

# %%
# Box plot for outlier detection in AGE
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['AGE'])
plt.title('Box Plot for Age')
plt.show()
# Calculate Q1, Q3, and IQR for AGE
q1 = df['AGE'].quantile(0.25)
q3 = df['AGE'].quantile(0.75)
iqr = q3 - q1

# Define outliers using the IQR method
outliers = df[(df['AGE'] < (q1 - 1.5 * iqr)) | (df['AGE'] > (q3 + 1.5 * iqr))]
print(outliers)
# Out:
# Empty DataFrame
# Columns: [GENDER, AGE, SMOKING, YELLOW_FINGERS, ANXIETY, PEER_PRESSURE, CHRONIC_DISEASE, FATIGUE, ALLERGY, WHEEZING, ALCOHOL_CONSUMING, COUGHING, SHORTNESS_OF_BREATH, SWALLOWING_DIFFICULTY, CHEST_PAIN, LUNG_CANCER]
# Index: []

# %% [markdown]
# ## Step 7: Hypothesis Testing
# Formulate hypotheses based on initial observations and test them using statistical methods.

# %%
from scipy.stats import ttest_ind

# Hypothesis: Fatigue levels are different between smokers and non-smokers
smoker_fatigue = df[df['SMOKING'] == 1]['FATIGUE']  # Fatigue levels of smokers
non_smoker_fatigue = df[df['SMOKING'] == 0]['FATIGUE']  # Fatigue levels of non-smokers

# Perform t-test
t_stat, p_value = ttest_ind(smoker_fatigue, non_smoker_fatigue)

print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: nan, P-value: nan

# %% [markdown]
# ## Step 8: Summarize Findings
# Compile insights and key findings from the EDA into a report.
# Use visualizations and statistical summaries to present your results.

# %%
df.groupby('CHRONIC_DISEASE')[['AGE', 'FATIGUE', 'SMOKING']].mean().T.plot(kind='barh', figsize=(10, 10))
plt.title('Average Age, Fatigue, and Smoking by Chronic Disease Status')
plt.xlabel('Average Value')
plt.ylabel('Variables')
plt.show()

# %%
df.groupby('SMOKING')[['AGE', 'YELLOW_FINGERS', 'PEER_PRESSURE']].mean().T.plot(kind='barh', figsize=(10, 10))
plt.title('Average Age, Yellow Fingers, and Peer Pressure by Smoking Status')
plt.xlabel('Average Value')
plt.ylabel('Variables')
plt.show()

# %% [markdown]
# # Key Insights for Lung Cancer Prediction
#
# ## 1. Impact of Smoking
# - **Insight**: Smoking is one of the most significant risk factors for lung cancer. Individuals with a history of smoking tend to have higher risks of developing lung cancer.
# - **Analysis**: Comparing the **`SMOKING`** variable across other features (such as **`AGE`**, **`FATIGUE`**, or **`CHEST_PAIN`**) can help determine how smoking correlates with various symptoms of lung cancer, such as fatigue or chest pain.
# - **Key Trend**: Higher smoking levels correlate with higher fatigue and increased difficulty in breathing.
#
# ---
#
# ## 2. Gender and Lung Cancer Risk
# - **Insight**: **`GENDER`** might influence the likelihood of lung cancer based on historical patterns and gender-specific behaviors.
# - **Analysis**: Use **`GENDER`** in relation to **`AGE`**, **`FATIGUE`**, and **`SMOKING`** to see if lung cancer manifests differently in men and women. This can highlight the importance of gender-based health approaches.
# - **Key Trend**: The prevalence of lung cancer might be different in males and females, with males possibly having a higher risk due to higher smoking rates.
#
# ---
#
# ## 3. Age and Risk Assessment
# - **Insight**: **`AGE`** is a significant predictor in lung cancer risk. Older individuals are at a higher risk of developing the disease, particularly if they have a history of smoking or other risk factors.
# - **Analysis**: By analyzing **`AGE`** in combination with other health factors (e.g., **`ANXIETY`**, **`SMOKING`**, **`FATIGUE`**), we can understand how age correlates with symptoms of lung cancer.
# - **Key Trend**: Increased age generally correlates with higher lung cancer risk, especially when coupled with high fatigue levels or smoking.
#
# ---
#
# ## 4. Chronic Diseases and Lung Cancer
# - **Insight**: The presence of **`CHRONIC_DISEASE`** can compound the risk of lung cancer, as chronic respiratory conditions often lead to more severe lung damage.
# - **Analysis**: Compare **`CHRONIC_DISEASE`** with other health factors like **`ANXIETY`**, **`FATIGUE`**, or **`SMOKING`** to determine the severity of symptoms and predict lung cancer.
# - **Key Trend**: People with chronic diseases (e.g., chronic bronchitis or emphysema) are more likely to experience worsened symptoms related to lung cancer.
#
# ---
#
# ## 5. Fatigue as a Key Symptom
# - **Insight**: **`FATIGUE`** is one of the early warning signs of lung cancer, and tracking its level can help in early detection.
# - **Analysis**: Look at how **`FATIGUE`** levels vary across **`AGE`**, **`SMOKING`**, and **`CHRONIC_DISEASE`**. High fatigue levels, when coupled with these factors, could increase the likelihood of lung cancer.
# - **Key Trend**: Increased fatigue correlates with higher lung cancer risk, especially in smokers or older individuals.
#
# ---
#
# ## 6. Chest Pain and Shortness of Breath
# - **Insight**: **`CHEST_PAIN`** and **`SHORTNESS_OF_BREATH`** are critical symptoms in diagnosing lung cancer.
# - **Analysis**: Analyzing these symptoms alongside **`AGE`**, **`SMOKING`**, and **`FATIGUE`** will help identify individuals who are more likely to develop lung cancer.
# - **Key Trend**: Those with chest pain and difficulty breathing are more likely to show early-stage lung cancer symptoms, especially if they also have a history of smoking.
#
# ---
#
# ## 7. Correlations Between Symptoms
# - **Insight**: Certain symptoms such as **`ANXIETY`**, **`ALLERGY`**, and **`WHEEZING`** may correlate with each other, indicating the progression of lung cancer.
# - **Analysis**: Correlating these symptoms with lung cancer status can help identify patterns and predict the likelihood of the disease.
# - **Key Trend**: Worsened anxiety or increased wheezing could be early indicators of lung cancer, especially in those with a history of smoking.
#
# ---
#
# ## 8. Statistical Testing for Risk Factors
# - **Insight**: Statistical tests (like **t-tests** or **chi-square tests**) can be useful in identifying significant differences in lung cancer risk based on various health factors such as **`AGE`**, **`SMOKING`**, **`FATIGUE`**, and **`GENDER`**.
# - **Analysis**: Use hypothesis testing to validate assumptions about lung cancer risk and to identify significant predictors.
# - **Key Trend**: Smoking and age are likely to be the most significant predictors of lung cancer based on the dataset.
#
# ---
#
# ## Conclusion:
# To effectively predict lung cancer, focus on key factors such as **`SMOKING`**, **`AGE`**, **`FATIGUE`**, **`GENDER`**, **`CHRONIC_DISEASE`**, and **`CHEST_PAIN`**. Advanced statistical analyses and machine learning models can be employed to combine these variables into a comprehensive risk assessment tool for early diagnosis.
#
# By identifying these key insights, we can better understand the relationships between lifestyle choices, symptoms, and lung cancer risk, leading to more targeted prevention and diagnosis strategies.
